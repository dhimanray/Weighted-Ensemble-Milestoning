# %% [markdown]
# **Jupyter: w_ipa**
#
# This is an example jupyter/ipython notebook for WESTPA simulations, designed for interactive analysis using w_ipa.  Use this as a template for further browser-based interactive analysis of simulations.
#
# You'll want to start each notebook session with the following:
#
# ```
#     import w_ipython
#     w = w_ipython.WIPI()
#     w.main()
# ```
#
# The w object can then be used for analysis.  Schemes can be listed and changed with
#
# ```
#     w.list_schemes
#     w.scheme = SCHEME_NUMBER/NAME
# ```
#
# Run help(w), or w.introduction for more details.
#
# Happy analyzing!

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
np.set_printoptions(threshold=np.inf)
import w_ipa
w = w_ipa.WIPI()
# At startup, it will load or run the analysis schemes specified in the configuration file (typically west.cfg)
w.main()
w.interface = 'matplotlib'
# Out:
# Welcome to w_ipa (WESTPA Interactive Python Analysis) v. 1.0B!
# Run w.introduction for a more thorough introduction, or w.help to see a list of options.
# Running analysis & loading files.
#
# Complete!
# Setting iteration to iter 1000.

# %%
total_iteration = 1000

it = [0.0 for i in range(total_iteration)]

flux = 0.0
flux_array = []
sink = 1.0

lifetime = 0.0
for i in range(total_iteration):
    w.iteration = i+1
    l = w.current.pcoord
    wts = w.current.weights
    tau = 501
    
    for j in range(len(l)):
        #print j
            
        if l[j][0] < sink and l[j][tau-1] >= sink:
            it[i] += wts[j]
            #print wts[j]
            for k in range(tau):
                if l[j][k] < sink and l[j][k+1] >= sink:
                    flux += wts[j]/float(i*tau+k)
                    lifetime += wts[j]*(i*tau+k)
                    break
            
    print flux
    flux_array.append(flux)
    
print "MFPT = ", 1./flux     
print "lifetime = ", lifetime
print sum(it)
print sum(it)/flux

f1 = open('milestone-data.dat','w')
print >>f1, "#MFPT  #MFPT_back  #lifetime  #forward probability  #backward probability"
print >>f1, 1./flux, 0.0, lifetime, 1.0, 0.0
f1.close()
# Out:
# Setting iteration to iter 1.
# 0.0
# Setting iteration to iter 2.
# 0.0
# Setting iteration to iter 3.
# 6.73364450026e-05
# Setting iteration to iter 4.
# 7.72341984764e-05
# Setting iteration to iter 5.
# 8.19669031188e-05
# Setting iteration to iter 6.
# 8.21262633017e-05
# Setting iteration to iter 7.
# 8.21616245789e-05
# Setting iteration to iter 8.
# 8.22813620281e-05
# Setting iteration to iter 9.
# 8.28543239382e-05
# Setting iteration to iter 10.
# 8.28878570346e-05
# Setting iteration to iter 11.
# 8.31181295181e-05
# Setting iteration to iter 12.
# 8.39103296974e-05
# Setting iteration to iter 13.
# 8.40667575104e-05
# Setting iteration to iter 14.
# 8.40888369258e-05
# Setting iteration to iter 15.
# 8.44214883938e-05
# Setting iteration to iter 16.
# 8.45689083977e-05
# Setting iteration to iter 17.
# 8.53111169103e-05
# Setting iteration to iter 18.
# 8.72924961188e-05
# Setting iteration to iter 19.
# 8.77066231265e-05
# Setting iteration to iter 20.
# 8.81918894416e-05
# Setting iteration to iter 21.
# 8.82336541813e-05
# Setting iteration to iter 22.
# 8.82443805805e-05
# Setting iteration to iter 23.
# 8.82464891571e-05
# Setting iteration to iter 24.
# 8.87555833344e-05
# Setting iteration to iter 25.
# 8.87629631498e-05
# Setting iteration to iter 26.
# 8.8785666811e-05
# Setting iteration to iter 27.
# 8.89778585603e-05
# Setting iteration to iter 28.
# 8.96247462283e-05
# Setting iteration to iter 29.
# 8.97648165434e-05
# Setting iteration to iter 30.
# 8.99371594015e-05
# Setting iteration to iter 31.
# 8.9965739947e-05
# Setting iteration to iter 32.
# 9.01267781711e-05
# Setting iteration to iter 33.
# 9.05761968252e-05
# Setting iteration to iter 34.
# 9.09882847502e-05
# Setting iteration to iter 35.
# 9.10861582835e-05
# Setting iteration to iter 36.
# 9.11146046802e-05
# Setting iteration to iter 37.
# 9.12184841829e-05
# Setting iteration to iter 38.
# 9.12639793583e-05
# Setting iteration to iter 39.
# 9.16886779577e-05
# Setting iteration to iter 40.
# 9.1778997379e-05
# Setting iteration to iter 41.
# 9.20740954998e-05
# Setting iteration to iter 42.
# 9.20811036384e-05
# Setting iteration to iter 43.
# 9.2150094509e-05
# Setting iteration to iter 44.
# 9.21668683863e-05
# Setting iteration to iter 45.
# 9.23248418215e-05
# Setting iteration to iter 46.
# 9.23946447474e-05
# Setting iteration to iter 47.
# 9.24822635533e-05
# Setting iteration to iter 48.
# 9.26115165218e-05
# Setting iteration to iter 49.
# 9.29746927708e-05
# Setting iteration to iter 50.
# 9.30083897113e-05
# Setting iteration to iter 51.
# 9.30943471987e-05
# Setting iteration to iter 52.
# 9.31418847097e-05
# Setting iteration to iter 53.
# 9.31936512393e-05
# Setting iteration to iter 54.
# 9.32007401107e-05
# Setting iteration to iter 55.
# 9.38570281886e-05
# Setting iteration to iter 56.
# 9.39914744084e-05
# Setting iteration to iter 57.
# 9.41769688527e-05
# Setting iteration to iter 58.
# 9.43146894668e-05
# Setting iteration to iter 59.
# 9.46710572017e-05
# Setting iteration to iter 60.
# 9.46798340621e-05
# Setting iteration to iter 61.
# 9.47614661613e-05
# Setting iteration to iter 62.
# 9.47673020057e-05
# Setting iteration to iter 63.
# 9.49740583992e-05
# Setting iteration to iter 64.
# 9.49741796718e-05
# Setting iteration to iter 65.
# 9.50485471784e-05
# Setting iteration to iter 66.
# 9.63144798401e-05
# Setting iteration to iter 67.
# 9.65785063112e-05
# Setting iteration to iter 68.
# 9.68484959984e-05
# Setting iteration to iter 69.
# 9.70145526437e-05
# Setting iteration to iter 70.
# 9.70434131205e-05
# Setting iteration to iter 71.
# 9.74552346615e-05
# Setting iteration to iter 72.
# 9.75528420817e-05
# Setting iteration to iter 73.
# 9.76212514949e-05
# Setting iteration to iter 74.
# 9.76647963114e-05
# Setting iteration to iter 75.
# 9.76686616581e-05
# Setting iteration to iter 76.
# 9.76698527216e-05
# Setting iteration to iter 77.
# 9.78211337798e-05
# Setting iteration to iter 78.
# 9.78211884149e-05
# Setting iteration to iter 79.
# 9.78854235774e-05
# Setting iteration to iter 80.
# 9.79252389627e-05
# Setting iteration to iter 81.
# 9.79340001725e-05
# Setting iteration to iter 82.
# 9.79349126398e-05
# Setting iteration to iter 83.
# 9.80187130111e-05
# Setting iteration to iter 84.
# 9.81150790729e-05
# Setting iteration to iter 85.
# 9.81940489306e-05
# Setting iteration to iter 86.
# 9.82139732665e-05
# Setting iteration to iter 87.
# 9.82365026478e-05
# Setting iteration to iter 88.
# 9.82368088009e-05
# Setting iteration to iter 89.
# 9.82368385186e-05
# Setting iteration to iter 90.
# 9.82487314443e-05
# Setting iteration to iter 91.
# 9.82546080864e-05
# Setting iteration to iter 92.
# 9.83779461275e-05
# Setting iteration to iter 93.
# 9.85178592929e-05
# Setting iteration to iter 94.
# 9.86229776053e-05
# Setting iteration to iter 95.
# 9.87602187651e-05
# Setting iteration to iter 96.
# 9.88977103272e-05
# Setting iteration to iter 97.
# 9.892143066e-05
# Setting iteration to iter 98.
# 9.89268620331e-05
# Setting iteration to iter 99.
# 9.8926972371e-05
# Setting iteration to iter 100.
# 9.91131200908e-05
# Setting iteration to iter 101.
# 9.91131244184e-05
# Setting iteration to iter 102.
# 9.91274838692e-05
# Setting iteration to iter 103.
# 9.91560185124e-05
# Setting iteration to iter 104.
# 9.91626009614e-05
# Setting iteration to iter 105.
# 9.91815438484e-05
# Setting iteration to iter 106.
# 9.9210959769e-05
# Setting iteration to iter 107.
# 9.92727145602e-05
# Setting iteration to iter 108.
# 9.93718299716e-05
# Setting iteration to iter 109.
# 9.93943375803e-05
# Setting iteration to iter 110.
# 9.9394475614e-05
# Setting iteration to iter 111.
# 9.93950468562e-05
# Setting iteration to iter 112.
# 9.93950468562e-05
# Setting iteration to iter 113.
# 9.95687091393e-05
# Setting iteration to iter 114.
# 9.95687239746e-05
# Setting iteration to iter 115.
# 9.95691822626e-05
# Setting iteration to iter 116.
# 9.95720234357e-05
# Setting iteration to iter 117.
# 9.95776233369e-05
# Setting iteration to iter 118.
# 9.9587699141e-05
# Setting iteration to iter 119.
# 9.97129288223e-05
# Setting iteration to iter 120.
# 9.97321683508e-05
# Setting iteration to iter 121.
# 9.97437344196e-05
# Setting iteration to iter 122.
# 9.97452074824e-05
# Setting iteration to iter 123.
# 9.97513840949e-05
# Setting iteration to iter 124.
# 9.97519723292e-05
# Setting iteration to iter 125.
# 9.97528573624e-05
# Setting iteration to iter 126.
# 9.97940289693e-05
# Setting iteration to iter 127.
# 9.98490268415e-05
# Setting iteration to iter 128.
# 9.98949604244e-05
# Setting iteration to iter 129.
# 9.9897807331e-05
# Setting iteration to iter 130.
# 9.99323312124e-05
# Setting iteration to iter 131.
# 9.99371600544e-05
# Setting iteration to iter 132.
# 9.99766477035e-05
# Setting iteration to iter 133.
# 9.99794488754e-05
# Setting iteration to iter 134.
# 9.99822227256e-05
# Setting iteration to iter 135.
# 9.99823023186e-05
# Setting iteration to iter 136.
# 0.000100018670172
# Setting iteration to iter 137.
# 0.000100018847772
# Setting iteration to iter 138.
# 0.000100025992493
# Setting iteration to iter 139.
# 0.000100026002144
# Setting iteration to iter 140.
# 0.000100026005572
# Setting iteration to iter 141.
# 0.000100108726771
# Setting iteration to iter 142.
# 0.000100115013994
# Setting iteration to iter 143.
# 0.000100117439243
# Setting iteration to iter 144.
# 0.000100146702681
# Setting iteration to iter 145.
# 0.000100161729635
# Setting iteration to iter 146.
# 0.000100169786028
# Setting iteration to iter 147.
# 0.000100404928359
# Setting iteration to iter 148.
# 0.000100418219587
# Setting iteration to iter 149.
# 0.000100435275894
# Setting iteration to iter 150.
# 0.000100442445536
# Setting iteration to iter 151.
# 0.000100444118443
# Setting iteration to iter 152.
# 0.000100474438943
# Setting iteration to iter 153.
# 0.000100493967298
# Setting iteration to iter 154.
# 0.000100496887745
# Setting iteration to iter 155.
# 0.000100524293521
# Setting iteration to iter 156.
# 0.000100619182182
# Setting iteration to iter 157.
# 0.000100630681994
# Setting iteration to iter 158.
# 0.000100642369067
# Setting iteration to iter 159.
# 0.000100665049079
# Setting iteration to iter 160.
# 0.000100681321386
# Setting iteration to iter 161.
# 0.000100723144338
# Setting iteration to iter 162.
# 0.000100741554566
# Setting iteration to iter 163.
# 0.00010076039977
# Setting iteration to iter 164.
# 0.000100761920377
# Setting iteration to iter 165.
# 0.000100762277312
# Setting iteration to iter 166.
# 0.000100796224792
# Setting iteration to iter 167.
# 0.00010083990862
# Setting iteration to iter 168.
# 0.000100879682401
# Setting iteration to iter 169.
# 0.000100889489061
# Setting iteration to iter 170.
# 0.000100890459426
# Setting iteration to iter 171.
# 0.000100891117052
# Setting iteration to iter 172.
# 0.000100891194363
# Setting iteration to iter 173.
# 0.000100902052746
# Setting iteration to iter 174.
# 0.000100912866168
# Setting iteration to iter 175.
# 0.000100925509822
# Setting iteration to iter 176.
# 0.000100952173474
# Setting iteration to iter 177.
# 0.000100995591628
# Setting iteration to iter 178.
# 0.000101008206321
# Setting iteration to iter 179.
# 0.000101015429265
# Setting iteration to iter 180.
# 0.0001010190449
# Setting iteration to iter 181.
# 0.00010102342343
# Setting iteration to iter 182.
# 0.000101120972313
# Setting iteration to iter 183.
# 0.000101132940154
# Setting iteration to iter 184.
# 0.000101145802798
# Setting iteration to iter 185.
# 0.000101157869335
# Setting iteration to iter 186.
# 0.000101205183041
# Setting iteration to iter 187.
# 0.000101309453681
# Setting iteration to iter 188.
# 0.000101417609526
# Setting iteration to iter 189.
# 0.000101421068943
# Setting iteration to iter 190.
# 0.000101424304971
# Setting iteration to iter 191.
# 0.000101566312809
# Setting iteration to iter 192.
# 0.000101601015765
# Setting iteration to iter 193.
# 0.000101602980437
# Setting iteration to iter 194.
# 0.000101613835404
# Setting iteration to iter 195.
# 0.000101806545273
# Setting iteration to iter 196.
# 0.000101882207992
# Setting iteration to iter 197.
# 0.000101900157264
# Setting iteration to iter 198.
# 0.00010193374304
# Setting iteration to iter 199.
# 0.000101952361497
# Setting iteration to iter 200.
# 0.000101957835262
# Setting iteration to iter 201.
# 0.000101959038968
# Setting iteration to iter 202.
# 0.000101965818595
# Setting iteration to iter 203.
# 0.0001019752973
# Setting iteration to iter 204.
# 0.000101978145279
# Setting iteration to iter 205.
# 0.000101996194964
# Setting iteration to iter 206.
# 0.00010203125622
# Setting iteration to iter 207.
# 0.000102041553297
# Setting iteration to iter 208.
# 0.000102042735541
# Setting iteration to iter 209.
# 0.000102048669217
# Setting iteration to iter 210.
# 0.000102127360364
# Setting iteration to iter 211.
# 0.000102132311051
# Setting iteration to iter 212.
# 0.000102155363968
# Setting iteration to iter 213.
# 0.000102183026467
# Setting iteration to iter 214.
# 0.00010219066513
# Setting iteration to iter 215.
# 0.000102196173296
# Setting iteration to iter 216.
# 0.000102197312986
# Setting iteration to iter 217.
# 0.000102231598182
# Setting iteration to iter 218.
# 0.000102244963365
# Setting iteration to iter 219.
# 0.000102252997273
# Setting iteration to iter 220.
# 0.000102262944242
# Setting iteration to iter 221.
# 0.000102269553958
# Setting iteration to iter 222.
# 0.000102283016167
# Setting iteration to iter 223.
# 0.000102288455945
# Setting iteration to iter 224.
# 0.000102291516778
# Setting iteration to iter 225.
# 0.000102298928074
# Setting iteration to iter 226.
# 0.000102300660354
# Setting iteration to iter 227.
# 0.000102302329679
# Setting iteration to iter 228.
# 0.000102306509815
# Setting iteration to iter 229.
# 0.000102372584925
# Setting iteration to iter 230.
# 0.000102384139679
# Setting iteration to iter 231.
# 0.000102467848535
# Setting iteration to iter 232.
# 0.000102488276666
# Setting iteration to iter 233.
# 0.000102501793383
# Setting iteration to iter 234.
# 0.000102502228044
# Setting iteration to iter 235.
# 0.00010250646035
# Setting iteration to iter 236.
# 0.000102508272413
# Setting iteration to iter 237.
# 0.000102575572818
# Setting iteration to iter 238.
# 0.00010259662963
# Setting iteration to iter 239.
# 0.000102608697197
# Setting iteration to iter 240.
# 0.000102610392552
# Setting iteration to iter 241.
# 0.000102627584465
# Setting iteration to iter 242.
# 0.000102633851638
# Setting iteration to iter 243.
# 0.000102638188938
# Setting iteration to iter 244.
# 0.000102641767526
# Setting iteration to iter 245.
# 0.000102646910961
# Setting iteration to iter 246.
# 0.000102649068691
# Setting iteration to iter 247.
# 0.000102649362153
# Setting iteration to iter 248.
# 0.000102653377236
# Setting iteration to iter 249.
# 0.000102659879963
# Setting iteration to iter 250.
# 0.000102663992112
# Setting iteration to iter 251.
# 0.000102690749542
# Setting iteration to iter 252.
# 0.000102696428129
# Setting iteration to iter 253.
# 0.000102771516989
# Setting iteration to iter 254.
# 0.000102772274796
# Setting iteration to iter 255.
# 0.000102779294668
# Setting iteration to iter 256.
# 0.000102791340269
# Setting iteration to iter 257.
# 0.000102827846363
# Setting iteration to iter 258.
# 0.000102836016188
# Setting iteration to iter 259.
# 0.000102843160655
# Setting iteration to iter 260.
# 0.000102854799149
# Setting iteration to iter 261.
# 0.000102857490915
# Setting iteration to iter 262.
# 0.000102862535588
# Setting iteration to iter 263.
# 0.000102896045415
# Setting iteration to iter 264.
# 0.000102899897083
# Setting iteration to iter 265.
# 0.000102901818432
# Setting iteration to iter 266.
# 0.000102905661926
# Setting iteration to iter 267.
# 0.000102906563126
# Setting iteration to iter 268.
# 0.000102906614424
# Setting iteration to iter 269.
# 0.000102915568849
# Setting iteration to iter 270.
# 0.000102924492039
# Setting iteration to iter 271.
# 0.000102925428229
# Setting iteration to iter 272.
# 0.000102935058234
# Setting iteration to iter 273.
# 0.000102938635103
# Setting iteration to iter 274.
# 0.000102939215111
# Setting iteration to iter 275.
# 0.000102939285086
# Setting iteration to iter 276.
# 0.00010293931625
# Setting iteration to iter 277.
# 0.000102957139993
# Setting iteration to iter 278.
# 0.000102958868199
# Setting iteration to iter 279.
# 0.000102981299501
# Setting iteration to iter 280.
# 0.00010299377399
# Setting iteration to iter 281.
# 0.000103006519909
# Setting iteration to iter 282.
# 0.000103012406116
# Setting iteration to iter 283.
# 0.000103016780451
# Setting iteration to iter 284.
# 0.000103017550654
# Setting iteration to iter 285.
# 0.000103018418166
# Setting iteration to iter 286.
# 0.000103019284824
# Setting iteration to iter 287.
# 0.000103019861075
# Setting iteration to iter 288.
# 0.000103020189713
# Setting iteration to iter 289.
# 0.000103028489109
# Setting iteration to iter 290.
# 0.00010302937968
# Setting iteration to iter 291.
# 0.000103034495399
# Setting iteration to iter 292.
# 0.000103037402138
# Setting iteration to iter 293.
# 0.0001030431238
# Setting iteration to iter 294.
# 0.000103051107654
# Setting iteration to iter 295.
# 0.000103059530666
# Setting iteration to iter 296.
# 0.000103072098783
# Setting iteration to iter 297.
# 0.000103082293138
# Setting iteration to iter 298.
# 0.000103086343421
# Setting iteration to iter 299.
# 0.000103087315561
# Setting iteration to iter 300.
# 0.000103103840379
# Setting iteration to iter 301.
# 0.000103111307583
# Setting iteration to iter 302.
# 0.000103114638366
# Setting iteration to iter 303.
# 0.000103116428755
# Setting iteration to iter 304.
# 0.0001031176795
# Setting iteration to iter 305.
# 0.000103139256936
# Setting iteration to iter 306.
# 0.000103142853046
# Setting iteration to iter 307.
# 0.000103145818212
# Setting iteration to iter 308.
# 0.000103149993377
# Setting iteration to iter 309.
# 0.000103150693613
# Setting iteration to iter 310.
# 0.000103155746791
# Setting iteration to iter 311.
# 0.000103155892246
# Setting iteration to iter 312.
# 0.000103158806643
# Setting iteration to iter 313.
# 0.000103160667155
# Setting iteration to iter 314.
# 0.000103167942673
# Setting iteration to iter 315.
# 0.000103180347832
# Setting iteration to iter 316.
# 0.000103185145696
# Setting iteration to iter 317.
# 0.000103201077241
# Setting iteration to iter 318.
# 0.000103203863564
# Setting iteration to iter 319.
# 0.000103204177731
# Setting iteration to iter 320.
# 0.000103209712373
# Setting iteration to iter 321.
# 0.000103210850262
# Setting iteration to iter 322.
# 0.000103213136625
# Setting iteration to iter 323.
# 0.000103220765139
# Setting iteration to iter 324.
# 0.000103220765153
# Setting iteration to iter 325.
# 0.00010322076517
# Setting iteration to iter 326.
# 0.000103220881023
# Setting iteration to iter 327.
# 0.000103220881024
# Setting iteration to iter 328.
# 0.000103232176123
# Setting iteration to iter 329.
# 0.000103232841468
# Setting iteration to iter 330.
# 0.000103234814522
# Setting iteration to iter 331.
# 0.000103243760823
# Setting iteration to iter 332.
# 0.000103264734683
# Setting iteration to iter 333.
# 0.000103267591022
# Setting iteration to iter 334.
# 0.000103282547592
# Setting iteration to iter 335.
# 0.000103283307275
# Setting iteration to iter 336.
# 0.000103284544097
# Setting iteration to iter 337.
# 0.000103284545503
# Setting iteration to iter 338.
# 0.000103286205211
# Setting iteration to iter 339.
# 0.000103288134935
# Setting iteration to iter 340.
# 0.000103289390891
# Setting iteration to iter 341.
# 0.000103290312885
# Setting iteration to iter 342.
# 0.000103295251422
# Setting iteration to iter 343.
# 0.000103296589502
# Setting iteration to iter 344.
# 0.000103303065407
# Setting iteration to iter 345.
# 0.00010331249418
# Setting iteration to iter 346.
# 0.000103315161523
# Setting iteration to iter 347.
# 0.000103323266043
# Setting iteration to iter 348.
# 0.00010332333684
# Setting iteration to iter 349.
# 0.000103325020285
# Setting iteration to iter 350.
# 0.000103325586925
# Setting iteration to iter 351.
# 0.000103326908459
# Setting iteration to iter 352.
# 0.000103326908481
# Setting iteration to iter 353.
# 0.00010332821107
# Setting iteration to iter 354.
# 0.00010333103335
# Setting iteration to iter 355.
# 0.000103335902616
# Setting iteration to iter 356.
# 0.000103337231159
# Setting iteration to iter 357.
# 0.000103340100951
# Setting iteration to iter 358.
# 0.000103343834587
# Setting iteration to iter 359.
# 0.000103348516582
# Setting iteration to iter 360.
# 0.000103355967694
# Setting iteration to iter 361.
# 0.000103357100166
# Setting iteration to iter 362.
# 0.000103364871152
# Setting iteration to iter 363.
# 0.000103369498373
# Setting iteration to iter 364.
# 0.000103371855072
# Setting iteration to iter 365.
# 0.000103374214433
# Setting iteration to iter 366.
# 0.000103374214433
# Setting iteration to iter 367.
# 0.000103375030291
# Setting iteration to iter 368.
# 0.000103377355326
# Setting iteration to iter 369.
# 0.000103377940814
# Setting iteration to iter 370.
# 0.000103379706793
# Setting iteration to iter 371.
# 0.000103383617663
# Setting iteration to iter 372.
# 0.000103406793366
# Setting iteration to iter 373.
# 0.000103412269682
# Setting iteration to iter 374.
# 0.000103413141346
# Setting iteration to iter 375.
# 0.000103423962506
# Setting iteration to iter 376.
# 0.00010342429738
# Setting iteration to iter 377.
# 0.000103424759503
# Setting iteration to iter 378.
# 0.000103424929765
# Setting iteration to iter 379.
# 0.000103427292403
# Setting iteration to iter 380.
# 0.000103427867324
# Setting iteration to iter 381.
# 0.000103429144865
# Setting iteration to iter 382.
# 0.000103429423946
# Setting iteration to iter 383.
# 0.000103431619992
# Setting iteration to iter 384.
# 0.000103431623763
# Setting iteration to iter 385.
# 0.000103440681462
# Setting iteration to iter 386.
# 0.000103444503756
# Setting iteration to iter 387.
# 0.000103446417199
# Setting iteration to iter 388.
# 0.000103447184517
# Setting iteration to iter 389.
# 0.000103447524308
# Setting iteration to iter 390.
# 0.000103447563551
# Setting iteration to iter 391.
# 0.00010344891354
# Setting iteration to iter 392.
# 0.000103452429229
# Setting iteration to iter 393.
# 0.000103452802377
# Setting iteration to iter 394.
# 0.000103475160146
# Setting iteration to iter 395.
# 0.00010347751994
# Setting iteration to iter 396.
# 0.000103481398727
# Setting iteration to iter 397.
# 0.000103483412954
# Setting iteration to iter 398.
# 0.000103489491837
# Setting iteration to iter 399.
# 0.000103492810644
# Setting iteration to iter 400.
# 0.000103501126526
# Setting iteration to iter 401.
# 0.000103501507173
# Setting iteration to iter 402.
# 0.000103501580449
# Setting iteration to iter 403.
# 0.00010350211912
# Setting iteration to iter 404.
# 0.000103502119123
# Setting iteration to iter 405.
# 0.000103502322808
# Setting iteration to iter 406.
# 0.000103513405636
# Setting iteration to iter 407.
# 0.000103515812137
# Setting iteration to iter 408.
# 0.000103518273462
# Setting iteration to iter 409.
# 0.00010351831201
# Setting iteration to iter 410.
# 0.0001035236843
# Setting iteration to iter 411.
# 0.000103525682926
# Setting iteration to iter 412.
# 0.000103535166045
# Setting iteration to iter 413.
# 0.000103537887415
# Setting iteration to iter 414.
# 0.000103538584516
# Setting iteration to iter 415.
# 0.000103544579714
# Setting iteration to iter 416.
# 0.000103549962536
# Setting iteration to iter 417.
# 0.000103553009287
# Setting iteration to iter 418.
# 0.000103565063664
# Setting iteration to iter 419.
# 0.000103566384391
# Setting iteration to iter 420.
# 0.000103567301351
# Setting iteration to iter 421.
# 0.00010356732946
# Setting iteration to iter 422.
# 0.000103567340978
# Setting iteration to iter 423.
# 0.000103575040243
# Setting iteration to iter 424.
# 0.000103575041443
# Setting iteration to iter 425.
# 0.000103575148432
# Setting iteration to iter 426.
# 0.000103582688361
# Setting iteration to iter 427.
# 0.000103588240355
# Setting iteration to iter 428.
# 0.000103588885795
# Setting iteration to iter 429.
# 0.000103590239472
# Setting iteration to iter 430.
# 0.000103590848504
# Setting iteration to iter 431.
# 0.000103592132376
# Setting iteration to iter 432.
# 0.000103593593011
# Setting iteration to iter 433.
# 0.00010359432129
# Setting iteration to iter 434.
# 0.000103598625657
# Setting iteration to iter 435.
# 0.000103599237532
# Setting iteration to iter 436.
# 0.000103599419369
# Setting iteration to iter 437.
# 0.000103602553978
# Setting iteration to iter 438.
# 0.000103612349909
# Setting iteration to iter 439.
# 0.000103617271372
# Setting iteration to iter 440.
# 0.000103619194472
# Setting iteration to iter 441.
# 0.000103619607389
# Setting iteration to iter 442.
# 0.00010362022113
# Setting iteration to iter 443.
# 0.000103624783
# Setting iteration to iter 444.
# 0.000103626598437
# Setting iteration to iter 445.
# 0.000103627321875
# Setting iteration to iter 446.
# 0.000103634188744
# Setting iteration to iter 447.
# 0.000103636134001
# Setting iteration to iter 448.
# 0.000103641283592
# Setting iteration to iter 449.
# 0.000103649655341
# Setting iteration to iter 450.
# 0.000103653060878
# Setting iteration to iter 451.
# 0.000103653144526
# Setting iteration to iter 452.
# 0.000103653931919
# Setting iteration to iter 453.
# 0.00010365556134
# Setting iteration to iter 454.
# 0.000103655969423
# Setting iteration to iter 455.
# 0.000103656216544
# Setting iteration to iter 456.
# 0.000103656384212
# Setting iteration to iter 457.
# 0.000103656625649
# Setting iteration to iter 458.
# 0.000103668800067
# Setting iteration to iter 459.
# 0.000103669129122
# Setting iteration to iter 460.
# 0.00010366915464
# Setting iteration to iter 461.
# 0.000103675172516
# Setting iteration to iter 462.
# 0.00010368266697
# Setting iteration to iter 463.
# 0.000103686082775
# Setting iteration to iter 464.
# 0.000103691482337
# Setting iteration to iter 465.
# 0.000103692778851
# Setting iteration to iter 466.
# 0.000103693375105
# Setting iteration to iter 467.
# 0.000103693482657
# Setting iteration to iter 468.
# 0.000103693652586
# Setting iteration to iter 469.
# 0.000103694976458
# Setting iteration to iter 470.
# 0.000103695505609
# Setting iteration to iter 471.
# 0.000103698045802
# Setting iteration to iter 472.
# 0.000103706277456
# Setting iteration to iter 473.
# 0.000103709047859
# Setting iteration to iter 474.
# 0.000103710032117
# Setting iteration to iter 475.
# 0.00010371050873
# Setting iteration to iter 476.
# 0.000103710622065
# Setting iteration to iter 477.
# 0.000103710629345
# Setting iteration to iter 478.
# 0.000103710676985
# Setting iteration to iter 479.
# 0.000103712040767
# Setting iteration to iter 480.
# 0.000103713394804
# Setting iteration to iter 481.
# 0.000103713520265
# Setting iteration to iter 482.
# 0.000103713521937
# Setting iteration to iter 483.
# 0.000103713546615
# Setting iteration to iter 484.
# 0.000103714633187
# Setting iteration to iter 485.
# 0.000103720862679
# Setting iteration to iter 486.
# 0.000103721625
# Setting iteration to iter 487.
# 0.000103735942319
# Setting iteration to iter 488.
# 0.000103735978202
# Setting iteration to iter 489.
# 0.000103738703308
# Setting iteration to iter 490.
# 0.00010374346716
# Setting iteration to iter 491.
# 0.000103744232196
# Setting iteration to iter 492.
# 0.000103745138135
# Setting iteration to iter 493.
# 0.000103745580605
# Setting iteration to iter 494.
# 0.000103748124856
# Setting iteration to iter 495.
# 0.000103750945681
# Setting iteration to iter 496.
# 0.000103751467122
# Setting iteration to iter 497.
# 0.000103753507669
# Setting iteration to iter 498.
# 0.000103757719665
# Setting iteration to iter 499.
# 0.000103760135854
# Setting iteration to iter 500.
# 0.000103760189777
# Setting iteration to iter 501.
# 0.000103760320073
# Setting iteration to iter 502.
# 0.000103760373617
# Setting iteration to iter 503.
# 0.000103761652161
# Setting iteration to iter 504.
# 0.000103761653184
# Setting iteration to iter 505.
# 0.000103761653588
# Setting iteration to iter 506.
# 0.000103761653664
# Setting iteration to iter 507.
# 0.000103761653702
# Setting iteration to iter 508.
# 0.000103761795792
# Setting iteration to iter 509.
# 0.000103762185992
# Setting iteration to iter 510.
# 0.000103762809546
# Setting iteration to iter 511.
# 0.000103763087664
# Setting iteration to iter 512.
# 0.000103763100083
# Setting iteration to iter 513.
# 0.000103764912605
# Setting iteration to iter 514.
# 0.000103764986686
# Setting iteration to iter 515.
# 0.000103765037682
# Setting iteration to iter 516.
# 0.000103765405069
# Setting iteration to iter 517.
# 0.000103765642257
# Setting iteration to iter 518.
# 0.00010376572086
# Setting iteration to iter 519.
# 0.000103766190058
# Setting iteration to iter 520.
# 0.00010376690241
# Setting iteration to iter 521.
# 0.00010377616092
# Setting iteration to iter 522.
# 0.00010377722165
# Setting iteration to iter 523.
# 0.000103777740323
# Setting iteration to iter 524.
# 0.000103777932636
# Setting iteration to iter 525.
# 0.000103777998158
# Setting iteration to iter 526.
# 0.000103781639952
# Setting iteration to iter 527.
# 0.000103782185828
# Setting iteration to iter 528.
# 0.000103782986285
# Setting iteration to iter 529.
# 0.000103787702616
# Setting iteration to iter 530.
# 0.000103788233518
# Setting iteration to iter 531.
# 0.000103788620241
# Setting iteration to iter 532.
# 0.000103788792207
# Setting iteration to iter 533.
# 0.000103788800559
# Setting iteration to iter 534.
# 0.000103789170117
# Setting iteration to iter 535.
# 0.000103789173957
# Setting iteration to iter 536.
# 0.000103789642172
# Setting iteration to iter 537.
# 0.000103789922134
# Setting iteration to iter 538.
# 0.000103791187256
# Setting iteration to iter 539.
# 0.000103791691592
# Setting iteration to iter 540.
# 0.000103795982066
# Setting iteration to iter 541.
# 0.000103799767923
# Setting iteration to iter 542.
# 0.00010380676539
# Setting iteration to iter 543.
# 0.000103806910917
# Setting iteration to iter 544.
# 0.00010380715432
# Setting iteration to iter 545.
# 0.00010380934581
# Setting iteration to iter 546.
# 0.000103809576045
# Setting iteration to iter 547.
# 0.000103809892564
# Setting iteration to iter 548.
# 0.000103809892564
# Setting iteration to iter 549.
# 0.000103809924482
# Setting iteration to iter 550.
# 0.000103810796403
# Setting iteration to iter 551.
# 0.000103816319896
# Setting iteration to iter 552.
# 0.00010381782077
# Setting iteration to iter 553.
# 0.000103818458044
# Setting iteration to iter 554.
# 0.000103818649439
# Setting iteration to iter 555.
# 0.000103819081894
# Setting iteration to iter 556.
# 0.000103819125713
# Setting iteration to iter 557.
# 0.000103819501678
# Setting iteration to iter 558.
# 0.000103819651911
# Setting iteration to iter 559.
# 0.000103821286184
# Setting iteration to iter 560.
# 0.000103821907226
# Setting iteration to iter 561.
# 0.000103822338703
# Setting iteration to iter 562.
# 0.000103822356179
# Setting iteration to iter 563.
# 0.000103822480817
# Setting iteration to iter 564.
# 0.000103822503359
# Setting iteration to iter 565.
# 0.000103822503359
# Setting iteration to iter 566.
# 0.000103822686276
# Setting iteration to iter 567.
# 0.000103822686293
# Setting iteration to iter 568.
# 0.000103822806527
# Setting iteration to iter 569.
# 0.000103825068667
# Setting iteration to iter 570.
# 0.000103825684563
# Setting iteration to iter 571.
# 0.000103826059995
# Setting iteration to iter 572.
# 0.00010382632574
# Setting iteration to iter 573.
# 0.000103826359805
# Setting iteration to iter 574.
# 0.000103826494012
# Setting iteration to iter 575.
# 0.000103826719735
# Setting iteration to iter 576.
# 0.000103826826879
# Setting iteration to iter 577.
# 0.000103827179619
# Setting iteration to iter 578.
# 0.000103836025318
# Setting iteration to iter 579.
# 0.000103836366269
# Setting iteration to iter 580.
# 0.000103836597092
# Setting iteration to iter 581.
# 0.000103836620272
# Setting iteration to iter 582.
# 0.000103836994365
# Setting iteration to iter 583.
# 0.000103837949155
# Setting iteration to iter 584.
# 0.000103838092963
# Setting iteration to iter 585.
# 0.000103839620392
# Setting iteration to iter 586.
# 0.000103839620397
# Setting iteration to iter 587.
# 0.000103839621325
# Setting iteration to iter 588.
# 0.000103839621695
# Setting iteration to iter 589.
# 0.00010384043389
# Setting iteration to iter 590.
# 0.000103840982551
# Setting iteration to iter 591.
# 0.000103841659152
# Setting iteration to iter 592.
# 0.000103841765936
# Setting iteration to iter 593.
# 0.000103842303231
# Setting iteration to iter 594.
# 0.000103842307042
# Setting iteration to iter 595.
# 0.000103842553663
# Setting iteration to iter 596.
# 0.000103842700683
# Setting iteration to iter 597.
# 0.000103842700774
# Setting iteration to iter 598.
# 0.000103842700816
# Setting iteration to iter 599.
# 0.00010384270082
# Setting iteration to iter 600.
# 0.000103843740922
# Setting iteration to iter 601.
# 0.000103844098798
# Setting iteration to iter 602.
# 0.000103844550261
# Setting iteration to iter 603.
# 0.000103844921389
# Setting iteration to iter 604.
# 0.000103844958026
# Setting iteration to iter 605.
# 0.000103845275865
# Setting iteration to iter 606.
# 0.000103845292043
# Setting iteration to iter 607.
# 0.000103845593032
# Setting iteration to iter 608.
# 0.000103845835944
# Setting iteration to iter 609.
# 0.000103846713921
# Setting iteration to iter 610.
# 0.000103847469616
# Setting iteration to iter 611.
# 0.000103847818222
# Setting iteration to iter 612.
# 0.000103847934152
# Setting iteration to iter 613.
# 0.000103847962198
# Setting iteration to iter 614.
# 0.00010384844667
# Setting iteration to iter 615.
# 0.000103848548005
# Setting iteration to iter 616.
# 0.000103848548844
# Setting iteration to iter 617.
# 0.000103849212698
# Setting iteration to iter 618.
# 0.0001038500094
# Setting iteration to iter 619.
# 0.000103850373191
# Setting iteration to iter 620.
# 0.000103850564608
# Setting iteration to iter 621.
# 0.000103851369783
# Setting iteration to iter 622.
# 0.000103851908418
# Setting iteration to iter 623.
# 0.000103852301962
# Setting iteration to iter 624.
# 0.0001038525065
# Setting iteration to iter 625.
# 0.000103852880685
# Setting iteration to iter 626.
# 0.000103853142317
# Setting iteration to iter 627.
# 0.000103853442029
# Setting iteration to iter 628.
# 0.000103854499741
# Setting iteration to iter 629.
# 0.000103854990567
# Setting iteration to iter 630.
# 0.000103855028451
# Setting iteration to iter 631.
# 0.000103857329364
# Setting iteration to iter 632.
# 0.00010385835125
# Setting iteration to iter 633.
# 0.000103859134115
# Setting iteration to iter 634.
# 0.00010386033189
# Setting iteration to iter 635.
# 0.000103861325654
# Setting iteration to iter 636.
# 0.000103861850737
# Setting iteration to iter 637.
# 0.000103862309138
# Setting iteration to iter 638.
# 0.000103862476534
# Setting iteration to iter 639.
# 0.000103862564243
# Setting iteration to iter 640.
# 0.000103862991408
# Setting iteration to iter 641.
# 0.000103863213125
# Setting iteration to iter 642.
# 0.000103863381209
# Setting iteration to iter 643.
# 0.000103863786021
# Setting iteration to iter 644.
# 0.000103863936419
# Setting iteration to iter 645.
# 0.00010386471044
# Setting iteration to iter 646.
# 0.000103864913782
# Setting iteration to iter 647.
# 0.000103864989156
# Setting iteration to iter 648.
# 0.000103865320063
# Setting iteration to iter 649.
# 0.000103865515582
# Setting iteration to iter 650.
# 0.000103866170053
# Setting iteration to iter 651.
# 0.000103866216209
# Setting iteration to iter 652.
# 0.000103869447615
# Setting iteration to iter 653.
# 0.000103870166925
# Setting iteration to iter 654.
# 0.000103870166925
# Setting iteration to iter 655.
# 0.000103870182607
# Setting iteration to iter 656.
# 0.000103870182636
# Setting iteration to iter 657.
# 0.000103870363713
# Setting iteration to iter 658.
# 0.000103870862269
# Setting iteration to iter 659.
# 0.000103871006959
# Setting iteration to iter 660.
# 0.000103871061001
# Setting iteration to iter 661.
# 0.000103871068421
# Setting iteration to iter 662.
# 0.000103871922866
# Setting iteration to iter 663.
# 0.00010387240902
# Setting iteration to iter 664.
# 0.000103872568736
# Setting iteration to iter 665.
# 0.00010387263714
# Setting iteration to iter 666.
# 0.000103872641044
# Setting iteration to iter 667.
# 0.000103872654841
# Setting iteration to iter 668.
# 0.00010387431186
# Setting iteration to iter 669.
# 0.000103874312743
# Setting iteration to iter 670.
# 0.000103874334994
# Setting iteration to iter 671.
# 0.000103874457571
# Setting iteration to iter 672.
# 0.000103874546647
# Setting iteration to iter 673.
# 0.000103874559838
# Setting iteration to iter 674.
# 0.000103874559838
# Setting iteration to iter 675.
# 0.000103874559838
# Setting iteration to iter 676.
# 0.000103874559838
# Setting iteration to iter 677.
# 0.000103874686239
# Setting iteration to iter 678.
# 0.000103875092401
# Setting iteration to iter 679.
# 0.000103875227068
# Setting iteration to iter 680.
# 0.000103875334644
# Setting iteration to iter 681.
# 0.000103875345378
# Setting iteration to iter 682.
# 0.000103875655899
# Setting iteration to iter 683.
# 0.000103875894391
# Setting iteration to iter 684.
# 0.00010387608947
# Setting iteration to iter 685.
# 0.000103876198353
# Setting iteration to iter 686.
# 0.000103876213296
# Setting iteration to iter 687.
# 0.000103876213296
# Setting iteration to iter 688.
# 0.000103876379121
# Setting iteration to iter 689.
# 0.000103876421252
# Setting iteration to iter 690.
# 0.000103876638452
# Setting iteration to iter 691.
# 0.000103877246049
# Setting iteration to iter 692.
# 0.000103877246056
# Setting iteration to iter 693.
# 0.000103878430528
# Setting iteration to iter 694.
# 0.000103878577354
# Setting iteration to iter 695.
# 0.000103879645629
# Setting iteration to iter 696.
# 0.000103879833091
# Setting iteration to iter 697.
# 0.000103880025117
# Setting iteration to iter 698.
# 0.000103880030571
# Setting iteration to iter 699.
# 0.000103880538752
# Setting iteration to iter 700.
# 0.000103880556637
# Setting iteration to iter 701.
# 0.00010388250894
# Setting iteration to iter 702.
# 0.000103882837263
# Setting iteration to iter 703.
# 0.00010388441809
# Setting iteration to iter 704.
# 0.00010388443923
# Setting iteration to iter 705.
# 0.000103884454211
# Setting iteration to iter 706.
# 0.000103884457215
# Setting iteration to iter 707.
# 0.000103884619239
# Setting iteration to iter 708.
# 0.000103885349161
# Setting iteration to iter 709.
# 0.000103885931277
# Setting iteration to iter 710.
# 0.000103885931281
# Setting iteration to iter 711.
# 0.000103885931281
# Setting iteration to iter 712.
# 0.000103889613407
# Setting iteration to iter 713.
# 0.000103889986723
# Setting iteration to iter 714.
# 0.000103891041822
# Setting iteration to iter 715.
# 0.000103891220781
# Setting iteration to iter 716.
# 0.000103891735363
# Setting iteration to iter 717.
# 0.000103892272708
# Setting iteration to iter 718.
# 0.00010389235644
# Setting iteration to iter 719.
# 0.000103892366011
# Setting iteration to iter 720.
# 0.000103892815204
# Setting iteration to iter 721.
# 0.000103892821693
# Setting iteration to iter 722.
# 0.00010389282621
# Setting iteration to iter 723.
# 0.000103893296269
# Setting iteration to iter 724.
# 0.000103893633273
# Setting iteration to iter 725.
# 0.000103894270596
# Setting iteration to iter 726.
# 0.000103894593778
# Setting iteration to iter 727.
# 0.000103895677334
# Setting iteration to iter 728.
# 0.000103896664266
# Setting iteration to iter 729.
# 0.000103896712291
# Setting iteration to iter 730.
# 0.000103896720635
# Setting iteration to iter 731.
# 0.000103897658314
# Setting iteration to iter 732.
# 0.000103897899151
# Setting iteration to iter 733.
# 0.000103898324474
# Setting iteration to iter 734.
# 0.000103898734685
# Setting iteration to iter 735.
# 0.00010390030458
# Setting iteration to iter 736.
# 0.000103900532355
# Setting iteration to iter 737.
# 0.000103901148017
# Setting iteration to iter 738.
# 0.000103901300828
# Setting iteration to iter 739.
# 0.000103901390047
# Setting iteration to iter 740.
# 0.000103901452945
# Setting iteration to iter 741.
# 0.000103901917237
# Setting iteration to iter 742.
# 0.000103902258471
# Setting iteration to iter 743.
# 0.000103903293948
# Setting iteration to iter 744.
# 0.000103903295275
# Setting iteration to iter 745.
# 0.000103903401443
# Setting iteration to iter 746.
# 0.000103903498523
# Setting iteration to iter 747.
# 0.000103903529766
# Setting iteration to iter 748.
# 0.000103903579048
# Setting iteration to iter 749.
# 0.000103903930465
# Setting iteration to iter 750.
# 0.000103904774903
# Setting iteration to iter 751.
# 0.000103904775178
# Setting iteration to iter 752.
# 0.000103905227605
# Setting iteration to iter 753.
# 0.000103905327874
# Setting iteration to iter 754.
# 0.000103905945525
# Setting iteration to iter 755.
# 0.000103906282772
# Setting iteration to iter 756.
# 0.00010390675162
# Setting iteration to iter 757.
# 0.000103907222096
# Setting iteration to iter 758.
# 0.000103907222099
# Setting iteration to iter 759.
# 0.000103907458933
# Setting iteration to iter 760.
# 0.000103907661385
# Setting iteration to iter 761.
# 0.000103908482372
# Setting iteration to iter 762.
# 0.000103908784475
# Setting iteration to iter 763.
# 0.000103909368086
# Setting iteration to iter 764.
# 0.000103910174214
# Setting iteration to iter 765.
# 0.000103910199952
# Setting iteration to iter 766.
# 0.000103910237813
# Setting iteration to iter 767.
# 0.000103910485554
# Setting iteration to iter 768.
# 0.000103910590395
# Setting iteration to iter 769.
# 0.00010391129879
# Setting iteration to iter 770.
# 0.000103911975085
# Setting iteration to iter 771.
# 0.00010391241767
# Setting iteration to iter 772.
# 0.000103912534894
# Setting iteration to iter 773.
# 0.000103912672375
# Setting iteration to iter 774.
# 0.000103912673228
# Setting iteration to iter 775.
# 0.000103912934098
# Setting iteration to iter 776.
# 0.000103914168958
# Setting iteration to iter 777.
# 0.000103914488793
# Setting iteration to iter 778.
# 0.000103914491465
# Setting iteration to iter 779.
# 0.00010391480653
# Setting iteration to iter 780.
# 0.000103914877009
# Setting iteration to iter 781.
# 0.000103915025694
# Setting iteration to iter 782.
# 0.000103915078123
# Setting iteration to iter 783.
# 0.000103915211208
# Setting iteration to iter 784.
# 0.000103915932196
# Setting iteration to iter 785.
# 0.000103916409057
# Setting iteration to iter 786.
# 0.000103916434343
# Setting iteration to iter 787.
# 0.000103916472249
# Setting iteration to iter 788.
# 0.000103916916345
# Setting iteration to iter 789.
# 0.000103916991519
# Setting iteration to iter 790.
# 0.000103917164053
# Setting iteration to iter 791.
# 0.000103917575768
# Setting iteration to iter 792.
# 0.000103917580232
# Setting iteration to iter 793.
# 0.000103917582157
# Setting iteration to iter 794.
# 0.000103917661314
# Setting iteration to iter 795.
# 0.000103917978249
# Setting iteration to iter 796.
# 0.000103918047972
# Setting iteration to iter 797.
# 0.00010391810464
# Setting iteration to iter 798.
# 0.000103918360079
# Setting iteration to iter 799.
# 0.000103918410414
# Setting iteration to iter 800.
# 0.000103918500692
# Setting iteration to iter 801.
# 0.0001039198605
# Setting iteration to iter 802.
# 0.000103919863591
# Setting iteration to iter 803.
# 0.000103919882257
# Setting iteration to iter 804.
# 0.000103919883575
# Setting iteration to iter 805.
# 0.000103919927594
# Setting iteration to iter 806.
# 0.000103920056483
# Setting iteration to iter 807.
# 0.000103920190023
# Setting iteration to iter 808.
# 0.000103920233759
# Setting iteration to iter 809.
# 0.000103921140045
# Setting iteration to iter 810.
# 0.000103921320897
# Setting iteration to iter 811.
# 0.000103921659573
# Setting iteration to iter 812.
# 0.000103921791092
# Setting iteration to iter 813.
# 0.000103921889087
# Setting iteration to iter 814.
# 0.000103921894426
# Setting iteration to iter 815.
# 0.000103922292446
# Setting iteration to iter 816.
# 0.000103922723704
# Setting iteration to iter 817.
# 0.000103922864376
# Setting iteration to iter 818.
# 0.000103922868576
# Setting iteration to iter 819.
# 0.00010392287615
# Setting iteration to iter 820.
# 0.000103922882234
# Setting iteration to iter 821.
# 0.000103923108298
# Setting iteration to iter 822.
# 0.000103923124548
# Setting iteration to iter 823.
# 0.000103923343677
# Setting iteration to iter 824.
# 0.000103923348135
# Setting iteration to iter 825.
# 0.000103923348274
# Setting iteration to iter 826.
# 0.000103924009263
# Setting iteration to iter 827.
# 0.000103924009281
# Setting iteration to iter 828.
# 0.000103924018387
# Setting iteration to iter 829.
# 0.000103924057027
# Setting iteration to iter 830.
# 0.000103924057027
# Setting iteration to iter 831.
# 0.000103924116182
# Setting iteration to iter 832.
# 0.000103924116182
# Setting iteration to iter 833.
# 0.00010392421193
# Setting iteration to iter 834.
# 0.000103924253223
# Setting iteration to iter 835.
# 0.000103924342828
# Setting iteration to iter 836.
# 0.000103924351532
# Setting iteration to iter 837.
# 0.000103924492795
# Setting iteration to iter 838.
# 0.000103924493386
# Setting iteration to iter 839.
# 0.000103924495897
# Setting iteration to iter 840.
# 0.000103924666958
# Setting iteration to iter 841.
# 0.000103924701221
# Setting iteration to iter 842.
# 0.000103925228649
# Setting iteration to iter 843.
# 0.00010392543173
# Setting iteration to iter 844.
# 0.000103925731269
# Setting iteration to iter 845.
# 0.000103926265598
# Setting iteration to iter 846.
# 0.000103926338393
# Setting iteration to iter 847.
# 0.000103926380801
# Setting iteration to iter 848.
# 0.000103926429492
# Setting iteration to iter 849.
# 0.000103927047538
# Setting iteration to iter 850.
# 0.000103927047592
# Setting iteration to iter 851.
# 0.000103927267871
# Setting iteration to iter 852.
# 0.000103927270685
# Setting iteration to iter 853.
# 0.000103927311797
# Setting iteration to iter 854.
# 0.000103927311798
# Setting iteration to iter 855.
# 0.000103927315304
# Setting iteration to iter 856.
# 0.000103927316472
# Setting iteration to iter 857.
# 0.000103927357908
# Setting iteration to iter 858.
# 0.0001039273785
# Setting iteration to iter 859.
# 0.000103927416847
# Setting iteration to iter 860.
# 0.000103927486899
# Setting iteration to iter 861.
# 0.000103927522601
# Setting iteration to iter 862.
# 0.000103927527229
# Setting iteration to iter 863.
# 0.000103928413664
# Setting iteration to iter 864.
# 0.000103928429048
# Setting iteration to iter 865.
# 0.000103928429048
# Setting iteration to iter 866.
# 0.000103928429048
# Setting iteration to iter 867.
# 0.000103928445618
# Setting iteration to iter 868.
# 0.000103928500812
# Setting iteration to iter 869.
# 0.000103929266471
# Setting iteration to iter 870.
# 0.000103929297178
# Setting iteration to iter 871.
# 0.000103929414
# Setting iteration to iter 872.
# 0.000103929689731
# Setting iteration to iter 873.
# 0.000103929726967
# Setting iteration to iter 874.
# 0.000103929983307
# Setting iteration to iter 875.
# 0.000103930135476
# Setting iteration to iter 876.
# 0.000103930382475
# Setting iteration to iter 877.
# 0.000103930426029
# Setting iteration to iter 878.
# 0.000103930467051
# Setting iteration to iter 879.
# 0.000103930509958
# Setting iteration to iter 880.
# 0.000103930609754
# Setting iteration to iter 881.
# 0.000103930701033
# Setting iteration to iter 882.
# 0.000103930708898
# Setting iteration to iter 883.
# 0.000103930709212
# Setting iteration to iter 884.
# 0.000103930838637
# Setting iteration to iter 885.
# 0.00010393083997
# Setting iteration to iter 886.
# 0.00010393083998
# Setting iteration to iter 887.
# 0.000103930854299
# Setting iteration to iter 888.
# 0.000103930865744
# Setting iteration to iter 889.
# 0.000103931144093
# Setting iteration to iter 890.
# 0.000103931183633
# Setting iteration to iter 891.
# 0.000103931263978
# Setting iteration to iter 892.
# 0.000103931298018
# Setting iteration to iter 893.
# 0.000103931356987
# Setting iteration to iter 894.
# 0.000103931374742
# Setting iteration to iter 895.
# 0.00010393143163
# Setting iteration to iter 896.
# 0.000103931644746
# Setting iteration to iter 897.
# 0.000103931690686
# Setting iteration to iter 898.
# 0.000103931819341
# Setting iteration to iter 899.
# 0.000103931857539
# Setting iteration to iter 900.
# 0.000103931923881
# Setting iteration to iter 901.
# 0.00010393192469
# Setting iteration to iter 902.
# 0.000103931933261
# Setting iteration to iter 903.
# 0.000103931948638
# Setting iteration to iter 904.
# 0.000103931986587
# Setting iteration to iter 905.
# 0.000103931987732
# Setting iteration to iter 906.
# 0.000103932017495
# Setting iteration to iter 907.
# 0.000103932037364
# Setting iteration to iter 908.
# 0.00010393204186
# Setting iteration to iter 909.
# 0.000103932146877
# Setting iteration to iter 910.
# 0.000103932169218
# Setting iteration to iter 911.
# 0.000103932686788
# Setting iteration to iter 912.
# 0.000103932816078
# Setting iteration to iter 913.
# 0.000103932907219
# Setting iteration to iter 914.
# 0.000103932921912
# Setting iteration to iter 915.
# 0.000103933034775
# Setting iteration to iter 916.
# 0.000103933046961
# Setting iteration to iter 917.
# 0.000103933054537
# Setting iteration to iter 918.
# 0.000103933151278
# Setting iteration to iter 919.
# 0.000103933151281
# Setting iteration to iter 920.
# 0.000103933198122
# Setting iteration to iter 921.
# 0.00010393361604
# Setting iteration to iter 922.
# 0.000103933708119
# Setting iteration to iter 923.
# 0.000103933784055
# Setting iteration to iter 924.
# 0.000103934533792
# Setting iteration to iter 925.
# 0.000103934719613
# Setting iteration to iter 926.
# 0.000103934911688
# Setting iteration to iter 927.
# 0.000103934969419
# Setting iteration to iter 928.
# 0.000103934990909
# Setting iteration to iter 929.
# 0.000103935071146
# Setting iteration to iter 930.
# 0.000103935128885
# Setting iteration to iter 931.
# 0.000103935197157
# Setting iteration to iter 932.
# 0.000103935200271
# Setting iteration to iter 933.
# 0.00010393526202
# Setting iteration to iter 934.
# 0.000103935286253
# Setting iteration to iter 935.
# 0.000103935286268
# Setting iteration to iter 936.
# 0.000103935289747
# Setting iteration to iter 937.
# 0.000103935327235
# Setting iteration to iter 938.
# 0.000103935327235
# Setting iteration to iter 939.
# 0.000103935523234
# Setting iteration to iter 940.
# 0.000103935523234
# Setting iteration to iter 941.
# 0.000103935523234
# Setting iteration to iter 942.
# 0.000103935629739
# Setting iteration to iter 943.
# 0.000103935694019
# Setting iteration to iter 944.
# 0.000103935798986
# Setting iteration to iter 945.
# 0.000103935844257
# Setting iteration to iter 946.
# 0.000103935900668
# Setting iteration to iter 947.
# 0.000103935955746
# Setting iteration to iter 948.
# 0.000103936062285
# Setting iteration to iter 949.
# 0.000103936192213
# Setting iteration to iter 950.
# 0.000103936405471
# Setting iteration to iter 951.
# 0.000103936593473
# Setting iteration to iter 952.
# 0.000103936685293
# Setting iteration to iter 953.
# 0.000103936697382
# Setting iteration to iter 954.
# 0.000103936786596
# Setting iteration to iter 955.
# 0.00010393710734
# Setting iteration to iter 956.
# 0.000103937232032
# Setting iteration to iter 957.
# 0.000103937367973
# Setting iteration to iter 958.
# 0.000103937374088
# Setting iteration to iter 959.
# 0.000103937703486
# Setting iteration to iter 960.
# 0.000103937710068
# Setting iteration to iter 961.
# 0.000103937773101
# Setting iteration to iter 962.
# 0.000103938278307
# Setting iteration to iter 963.
# 0.000103938292589
# Setting iteration to iter 964.
# 0.000103938368687
# Setting iteration to iter 965.
# 0.000103938368979
# Setting iteration to iter 966.
# 0.000103938368983
# Setting iteration to iter 967.
# 0.000103938368983
# Setting iteration to iter 968.
# 0.000103938591271
# Setting iteration to iter 969.
# 0.000103938819677
# Setting iteration to iter 970.
# 0.000103938954133
# Setting iteration to iter 971.
# 0.000103938954133
# Setting iteration to iter 972.
# 0.000103939219969
# Setting iteration to iter 973.
# 0.000103939444916
# Setting iteration to iter 974.
# 0.0001039396999
# Setting iteration to iter 975.
# 0.000103939730219
# Setting iteration to iter 976.
# 0.000103940027712
# Setting iteration to iter 977.
# 0.000103940067275
# Setting iteration to iter 978.
# 0.000103940075707
# Setting iteration to iter 979.
# 0.000103940092188
# Setting iteration to iter 980.
# 0.000103940115131
# Setting iteration to iter 981.
# 0.00010394018685
# Setting iteration to iter 982.
# 0.000103940310107
# Setting iteration to iter 983.
# 0.000103940407112
# Setting iteration to iter 984.
# 0.000103940434152
# Setting iteration to iter 985.
# 0.000103940438988
# Setting iteration to iter 986.
# 0.000103940444208
# Setting iteration to iter 987.
# 0.000103940446148
# Setting iteration to iter 988.
# 0.000103940485474
# Setting iteration to iter 989.
# 0.000103940494017
# Setting iteration to iter 990.
# 0.000103940502527
# Setting iteration to iter 991.
# 0.000103940502527
# Setting iteration to iter 992.
# 0.000103940502527
# Setting iteration to iter 993.
# 0.000103940502527
# Setting iteration to iter 994.
# 0.000103940652162
# Setting iteration to iter 995.
# 0.000103940712889
# Setting iteration to iter 996.
# 0.000103940738446
# Setting iteration to iter 997.
# 0.000103940753348
# Setting iteration to iter 998.
# 0.000103940765731
# Setting iteration to iter 999.
# 0.000103940769536
# Setting iteration to iter 1000.
# 0.000103940773023
# MFPT =  9620.86360256
# lifetime =  88971.029738
# 0.99244585365
# 9548.1861909

# %%
print "MFPT = ", float(tau)/flux
# Out:
# MFPT =  239.50827552432662

# %%
w.iteration = 8
final_trajectories = w.current.seg_id
traj_trace = w.trace(final_trajectories[149])
#print('What data can we access from our trace for segment {}?'.format(final_trajectories[45]))
#print(traj_trace.keys())
# Then plot something interesting about it, like the pcoord or the weight changes over time.
# The resulting plot is per time point, not iteration.
plt.plot(traj_trace['pcoord'])
plt.show()
print traj_trace['pcoord']
print len(np.array(traj_trace['pcoord']))
#print traj_trace['pcoord'].shape()
#plt.plot(np.log10(traj_trace['weights']))
#plt.show()
#trajectory = traj_trace['pcoord']
#print trajectory
# Out:
# Setting iteration to iter 8.
# array([[-1.30999994],
#        [-1.33999991],
#        [-1.33999991],
#        [-1.38999999],
#        [-1.41999996],
#        [-1.41999996],
#        [-1.40999997],
#        [-1.40999997],
#        [-1.44999993],
#        [-1.44999993],
#        [-1.40999997],
#        [-1.41999996],
#        [-1.41999996],
#        [-1.40999997],
#        [-1.38      ],
#        [-1.38      ],
#        [-1.31999993],
#        [-1.30999994],
#        [-1.32999992],
#        [-1.27999997],
#        [-1.29999995],
#        [-1.26999998],
#        [-1.25999999],
#        [-1.25      ],
#        [-1.27999997],
#        [-1.25      ],
#        [-1.32999992],
#        [-1.28999996],
#        [-1.25      ],
#        [-1.28999996],
#        [-1.31999993],
#        [-1.3499999 ],
#        [-1.3599999 ],
#        [-1.32999992],
#        [-1.3499999 ],
#        [-1.33999991],
#        [-1.38      ],
#        [-1.38999999],
#        [-1.37      ],
#        [-1.41999996],
#        [-1.44999993],
#        [-1.45999992],
#        [-1.44999993],
#        [-1.5       ],
#        [-1.44999993],
#        [-1.44999993],
#        [-1.45999992],
#        [-1.49000001],
#        [-1.47000003],
#        [-1.42999995],
#        [-1.41999996],
#        [-1.38999999],
#        [-1.39999998],
#        [-1.3599999 ],
#        [-1.33999991],
#        [-1.33999991],
#        [-1.31999993],
#        [-1.29999995],
#        [-1.25999999],
#        [-1.25999999],
#        [-1.25999999],
#        [-1.25999999],
#        [-1.25      ],
#        [-1.24000001],
#        [-1.28999996],
#        [-1.29999995],
#        [-1.25999999],
#        [-1.29999995],
#        [-1.24000001],
#        [-1.27999997],
#        [-1.27999997],
#        [-1.26999998],
#        [-1.28999996],
#        [-1.32999992],
#        [-1.31999993],
#        [-1.25999999],
#        [-1.25999999],
#        [-1.28999996],
#        [-1.32999992],
#        [-1.32999992],
#        [-1.38      ],
#        [-1.32999992],
#        [-1.30999994],
#        [-1.3499999 ],
#        [-1.38      ],
#        [-1.3599999 ],
#        [-1.38999999],
#        [-1.3599999 ],
#        [-1.33999991],
#        [-1.32999992],
#        [-1.29999995],
#        [-1.3599999 ],
#        [-1.32999992],
#        [-1.29999995],
#        [-1.26999998],
#        [-1.23000002],
#        [-1.21000004],
#        [-1.25999999],
#        [-1.28999996],
#        [-1.27999997],
#        [-1.22000003],
#        [-1.21999991],
#        [-1.17999983],
#        [-1.20999992],
#        [-1.19999993],
#        [-1.21999991],
#        [-1.18999982],
#        [-1.18999982],
#        [-1.15999985],
#        [-1.16999984],
#        [-1.14999986],
#        [-1.15999985],
#        [-1.08999991],
#        [-1.0999999 ],
#        [-1.0999999 ],
#        [-1.0999999 ],
#        [-1.11999989],
#        [-1.19999993],
#        [-1.17999983],
#        [-1.16999984],
#        [-1.21999991],
#        [-1.21999991],
#        [-1.2299999 ],
#        [-1.25999999],
#        [-1.24999988],
#        [-1.25999999],
#        [-1.23999989],
#        [-1.23999989],
#        [-1.20999992],
#        [-1.18999982],
#        [-1.20999992],
#        [-1.24999988],
#        [-1.19999993],
#        [-1.18999982],
#        [-1.20999992],
#        [-1.19999993],
#        [-1.2299999 ],
#        [-1.17999983],
#        [-1.14999986],
#        [-1.14999986],
#        [-1.16999984],
#        [-1.11999989],
#        [-1.1099999 ],
#        [-1.0999999 ],
#        [-1.12999988],
#        [-1.13999987],
#        [-1.21999991],
#        [-1.20999992],
#        [-1.24999988],
#        [-1.19999993],
#        [-1.18999982],
#        [-1.17999983],
#        [-1.16999984],
#        [-1.19999993],
#        [-1.18999982],
#        [-1.16999984],
#        [-1.18999982],
#        [-1.16999984],
#        [-1.18999982],
#        [-1.13999987],
#        [-1.21999991],
#        [-1.18999982],
#        [-1.16999984],
#        [-1.15999985],
#        [-1.16999984],
#        [-1.15999985],
#        [-1.1099999 ],
#        [-1.0999999 ],
#        [-1.07999992],
#        [-1.0999999 ],
#        [-1.11999989],
#        [-1.0999999 ],
#        [-1.08999991],
#        [-1.06999993],
#        [-1.02999985],
#        [-1.04999995],
#        [-1.0999999 ],
#        [-1.12999988],
#        [-1.11999989],
#        [-1.13999987],
#        [-1.18999982],
#        [-1.19999993],
#        [-1.15999985],
#        [-1.14999986],
#        [-1.15999985],
#        [-1.19999993],
#        [-1.23999989],
#        [-1.21999991],
#        [-1.19999993],
#        [-1.24999988],
#        [-1.25999999],
#        [-1.27999997],
#        [-1.26999998],
#        [-1.30999994],
#        [-1.26999998],
#        [-1.28999996],
#        [-1.29999995],
#        [-1.26999998],
#        [-1.26999998],
#        [-1.2299999 ],
#        [-1.19999993],
#        [-1.20999992],
#        [-1.21000004],
#        [-1.20000005],
#        [-1.19000006],
#        [-1.19000006],
#        [-1.21000004],
#        [-1.18000007],
#        [-1.13000011],
#        [-1.12000012],
#        [-1.08000004],
#        [-1.09000015],
#        [-1.09000015],
#        [-1.06000006],
#        [-1.13000011],
#        [-1.20000005],
#        [-1.16000009],
#        [-1.13000011],
#        [-1.13000011],
#        [-1.12000012],
#        [-1.11000013],
#        [-1.11000013],
#        [-1.04000008],
#        [-1.03000009],
#        [-1.08000004],
#        [-1.10000014],
#        [-1.10000014],
#        [-1.08000004],
#        [-1.12000012],
#        [-1.08000004],
#        [-1.06000006],
#        [-1.10000014],
#        [-1.12000012],
#        [-1.16000009],
#        [-1.1400001 ],
#        [-1.1500001 ],
#        [-1.16000009],
#        [-1.1400001 ],
#        [-1.20000005],
#        [-1.22000003],
#        [-1.23000002],
#        [-1.22000003],
#        [-1.18000007],
#        [-1.16000009],
#        [-1.10000014],
#        [-1.07000005],
#        [-1.06000006],
#        [-1.01000011],
#        [-0.96000004],
#        [-0.98000014],
#        [-1.0200001 ],
#        [-1.00000012],
#        [-1.00000012],
#        [-1.05000007],
#        [-1.08000004],
#        [-1.09000015],
#        [-1.04000008],
#        [-1.01000011],
#        [-1.00000012],
#        [-0.93000007],
#        [-0.94000006],
#        [-0.93000007],
#        [-0.92000008],
#        [-0.92000008],
#        [-0.9000001 ],
#        [-0.91000009],
#        [-0.91000009],
#        [-0.9000001 ],
#        [-0.88000011],
#        [-0.87000012],
#        [-0.83000004],
#        [-0.82000005],
#        [-0.87000012],
#        [-0.8900001 ],
#        [-0.87000012],
#        [-0.91000009],
#        [-0.95000005],
#        [-1.00000012],
#        [-0.98000014],
#        [-0.98000014],
#        [-1.00000012],
#        [-0.97000015],
#        [-0.99000013],
#        [-0.93000007],
#        [-0.91000009],
#        [-0.92000008],
#        [-0.8900001 ],
#        [-0.82000005],
#        [-0.84000015],
#        [-0.78000009],
#        [-0.81000006],
#        [-0.7700001 ],
#        [-0.79000008],
#        [-0.69000006],
#        [-0.69000006],
#        [-0.71000004],
#        [-0.72000015],
#        [-0.74000013],
#        [-0.72000015],
#        [-0.71000004],
#        [-0.70000005],
#        [-0.72000015],
#        [-0.68000007],
#        [-0.67999995],
#        [-0.67999995],
#        [-0.63      ],
#        [-0.64999998],
#        [-0.69999993],
#        [-0.75      ],
#        [-0.71999991],
#        [-0.68999994],
#        [-0.65999997],
#        [-0.67999995],
#        [-0.70999992],
#        [-0.77999997],
#        [-0.75      ],
#        [-0.79999995],
#        [-0.80999994],
#        [-0.82999992],
#        [-0.86000001],
#        [-0.83999991],
#        [-0.86000001],
#        [-0.78999996],
#        [-0.75      ],
#        [-0.70999992],
#        [-0.61000001],
#        [-0.57999992],
#        [-0.56999993],
#        [-0.56999993],
#        [-0.55999994],
#        [-0.57999992],
#        [-0.64999998],
#        [-0.61000001],
#        [-0.53999996],
#        [-0.52999997],
#        [-0.50999999],
#        [-0.50999999],
#        [-0.5       ],
#        [-0.52999997],
#        [-0.51999998],
#        [-0.50999999],
#        [-0.50999999],
#        [-0.45000005],
#        [-0.43000007],
#        [-0.42000008],
#        [-0.44000006],
#        [-0.36999989],
#        [-0.33999991],
#        [-0.30999994],
#        [-0.30999994],
#        [-0.33999991],
#        [-0.28999996],
#        [-0.24000001],
#        [-0.23000002],
#        [-0.20000005],
#        [-0.22000003],
#        [-0.20000005],
#        [-0.17000008],
#        [-0.12999988],
#        [-0.13999987],
#        [-0.08999991],
#        [-0.07999992],
#        [-0.05999994],
#        [-0.0999999 ],
#        [-0.08999991],
#        [-0.08999991],
#        [-0.03999996],
#        [-0.03999996],
#        [-0.03999996],
#        [-0.01999998],
#        [-0.03999996],
#        [-0.01999998],
#        [-0.05999994],
#        [-0.04999995],
#        [-0.01999998],
#        [-0.03999996],
#        [-0.03999996],
#        [-0.02999997],
#        [-0.01999998],
#        [-0.02999997],
#        [-0.00999999],
#        [-0.00999999],
#        [-0.02999997],
#        [ 0.03999996],
#        [ 0.00999999],
#        [ 0.05999994],
#        [ 0.09000015],
#        [ 0.1400001 ],
#        [ 0.16000009],
#        [ 0.1500001 ],
#        [ 0.1500001 ],
#        [ 0.17000008],
#        [ 0.13000011],
#        [ 0.13000011],
#        [ 0.1500001 ],
#        [ 0.18000007],
#        [ 0.19000006],
#        [ 0.22000003],
#        [ 0.25      ],
#        [ 0.28999996],
#        [ 0.28999996],
#        [ 0.29999995],
#        [ 0.29999995],
#        [ 0.27999997],
#        [ 0.27999997],
#        [ 0.25      ],
#        [ 0.27999997],
#        [ 0.25999999],
#        [ 0.25999999],
#        [ 0.30999994],
#        [ 0.26999998],
#        [ 0.25999999],
#        [ 0.29999995],
#        [ 0.28999996],
#        [ 0.25999999],
#        [ 0.25999999],
#        [ 0.25      ],
#        [ 0.24000001],
#        [ 0.29999995],
#        [ 0.28999996],
#        [ 0.29999995],
#        [ 0.32999992],
#        [ 0.3499999 ],
#        [ 0.36999989],
#        [ 0.32999992],
#        [ 0.31999993],
#        [ 0.28999996],
#        [ 0.27999997],
#        [ 0.24000001],
#        [ 0.25      ],
#        [ 0.26999998],
#        [ 0.25999999],
#        [ 0.28999996],
#        [ 0.30999994],
#        [ 0.32999992],
#        [ 0.29999995],
#        [ 0.30999994],
#        [ 0.32999992],
#        [ 0.37999988],
#        [ 0.41999984],
#        [ 0.38999987],
#        [ 0.39999986],
#        [ 0.41999984],
#        [ 0.42999983],
#        [ 0.40999985],
#        [ 0.41999984],
#        [ 0.42999983],
#        [ 0.41999984],
#        [ 0.40999985],
#        [ 0.36999989],
#        [ 0.3599999 ],
#        [ 0.31999993],
#        [ 0.3599999 ],
#        [ 0.32999992],
#        [ 0.32999992],
#        [ 0.3499999 ],
#        [ 0.3599999 ],
#        [ 0.3599999 ],
#        [ 0.38999987],
#        [ 0.37999988],
#        [ 0.41999984],
#        [ 0.37999988],
#        [ 0.3499999 ],
#        [ 0.3499999 ],
#        [ 0.39999986],
#        [ 0.3499999 ],
#        [ 0.39999986],
#        [ 0.38999987],
#        [ 0.39999986],
#        [ 0.43999982],
#        [ 0.39999986],
#        [ 0.41999984],
#        [ 0.46999979],
#        [ 0.51999998],
#        [ 0.51999998],
#        [ 0.50999999],
#        [ 0.5       ],
#        [ 0.55999994],
#        [ 0.51999998],
#        [ 0.52999997],
#        [ 0.47999978],
#        [ 0.43999982],
#        [ 0.43999982],
#        [ 0.40999985],
#        [ 0.4599998 ],
#        [ 0.46999979],
#        [ 0.5       ],
#        [ 0.52999997],
#        [ 0.44999981],
#        [ 0.44999981],
#        [ 0.43999982],
#        [ 0.40999985],
#        [ 0.39999986],
#        [ 0.38999987],
#        [ 0.41999984],
#        [ 0.41999984],
#        [ 0.41999984],
#        [ 0.40999985],
#        [ 0.44999981],
#        [ 0.43999982],
#        [ 0.47999978],
#        [ 0.46999979],
#        [ 0.4599998 ],
#        [ 0.52999997],
#        [ 0.51999998],
#        [ 0.51999998],
#        [ 0.54999995],
#        [ 0.51999998],
#        [ 0.50999999],
#        [ 0.5       ],
#        [ 0.5       ],
#        [ 0.53999996],
#        [ 0.51999998],
#        [ 0.55999994],
#        [ 0.57999992],
#        [ 0.58999991],
#        [ 0.63999987],
#        [ 0.6099999 ],
#        [ 0.58999991],
#        [ 0.55999994],
#        [ 0.54999995],
#        [ 0.55999994],
#        [ 0.55999994],
#        [ 0.56999993],
#        [ 0.54999995],
#        [ 0.53999996],
#        [ 0.55999994],
#        [ 0.6099999 ],
#        [ 0.67000008],
#        [ 0.65999985],
#        [ 0.69000006],
#        [ 0.72000003],
#        [ 0.76999998],
#        [ 0.78999996],
#        [ 0.78999996],
#        [ 0.82999992],
#        [ 0.83999991],
#        [ 0.87999988],
#        [ 0.8599999 ],
#        [ 0.87999988],
#        [ 0.90999985],
#        [ 0.92000008],
#        [ 0.92000008],
#        [ 0.87999988],
#        [ 0.86999989],
#        [ 0.8499999 ],
#        [ 0.83999991],
#        [ 0.86999989],
#        [ 0.89999986],
#        [ 0.90999985],
#        [ 0.97000003],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.0400002 ],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996],
#        [ 1.03999996]], dtype=float32)
# 808

# %%
w.iteration = 1
w.current.bins
l1 = w.current.pcoord
print len(l1)
w.current
# Out:
# Setting iteration to iter 1.
# 10
# ['aggregate_walkers', 'auxdata', 'bins', 'color_prob_evolution', 'conditional_flux_evolution', 'direct', 'instant_matrix', 'iteration', 'matrix', 'maxweight', 'minweight', 'parent', 'parents', 'pcoord', 'rate_evolution', 'raw', 'reweight', 'seg_id', 'state_pop_evolution', 'states', 'successful_trajectories', 'summary', 'target_flux_evolution', 'total_fluxes', 'walkers', 'weights']

# %%
print it
f1 = open('FPTD.dat','w')

for i in range(len(it)):
    print >>f1, i*tau, it[i]
    
f1.close()
# Out:
# [0.0, 0.0, 0.080000000000000016, 0.017600000000000001, 0.010239999999999999, 0.00042666666666666677, 0.00011626666666666666, 0.00046634666666666639, 0.0024582399999999991, 0.00015630696296296302, 0.0012446151111111113, 0.0045905066666666666, 0.00098217698765432201, 0.00015319857777777778, 0.0024261598814814813, 0.0011467617444345683, 0.0060238650418567895, 0.01747736139602437, 0.0038497869811031453, 0.0047096244285538746, 0.00043044734791242785, 0.00011467258572510288, 2.3446381704533333e-05, 0.0060754772330411664, 8.9591785351108964e-05, 0.00028820799083659979, 0.0025491249187856745, 0.0089319111573083736, 0.001982617987481089, 0.0025412080675794486, 0.0004330351296547383, 0.0025489980371401007, 0.0072439646029630314, 0.0068265637391395403, 0.0017007702798009332, 0.00050350590982861242, 0.0018907096793907151, 0.00085559704017702147, 0.0081836759984587684, 0.0017883170524498181, 0.0059863066013646571, 0.0001448700257161641, 0.0014632653565175657, 0.00036486739010124422, 0.0035393623340711946, 0.0015907700882733977, 0.0020325416064335368, 0.0031044253804824729, 0.0088148971354984045, 0.00083760438291034399, 0.002168243707627185, 0.0012311473625877579, 0.0013650904137957171, 0.00019046020888571148, 0.017882529126634985, 0.0037518977620643939, 0.0052859701545700287, 0.0039687047200885391, 0.01042588233215147, 0.0002638060942415377, 0.0024717360760632841, 0.00017972153334079065, 0.006443336124847189, 3.8504617082033136e-06, 0.0023982781821149245, 0.041810772545678145, 0.0087792035157623714, 0.0091636404641011072, 0.0057014688980541539, 0.0010007980370872224, 0.014538499463108883, 0.0035011042769796611, 0.0024868232722842268, 0.0016022385812623698, 0.00014410447148165432, 4.4969842285075639e-05, 0.0057985987485066086, 2.116227872238854e-06, 0.0025300420598067517, 0.0015858067751122968, 0.00035420716824909027, 3.708390532833118e-05, 0.0034762564803315099, 0.0040513202300397344, 0.0033274542919390507, 0.00084983371108980372, 0.00097885677378167974, 1.3409689922906441e-05, 1.3206512802862408e-06, 0.00053314823311570816, 0.00026624914681505141, 0.0056734390121674257, 0.0064921724545201429, 0.0049225142164452326, 0.0065105982559582141, 0.0065734378353071287, 0.0011455679930039795, 0.00026502734929673139, 5.4414773781720436e-06, 0.0092521113632829857, 2.1765909512688173e-07, 0.00073210171818219208, 0.0014638525041406885, 0.00034220136920255545, 0.00099081770710225865, 0.0015550462220404507, 0.0032926317520766682, 0.0053421175863522579, 0.0012235800364770893, 7.5791556040600018e-06, 3.1579815016916678e-05, 0.0, 0.0098287489557391996, 8.4212840045111138e-07, 2.6274163252689825e-05, 0.00016470298087304744, 0.00032724118149380423, 0.00059485497122684994, 0.0074397974862286968, 0.0011529537266588685, 0.00069578529003437866, 8.943565092930411e-05, 0.00037956594865064583, 3.6435230815458244e-05, 5.5177878415850845e-05, 0.0025888657394114011, 0.0034831429266738321, 0.0029270243907290406, 0.00018309948813142327, 0.002243273149842477, 0.00031501969198196656, 0.002602648895394495, 0.00018566769919490476, 0.00018570409099448747, 5.3559457905477602e-06, 0.0024723720253606988, 1.2153130260861988e-05, 0.00049056746097026578, 6.6932922465535184e-07, 2.3968965715150981e-07, 0.0058246538791726903, 0.0004471378125320003, 0.00017342927801451734, 0.0020994460335382594, 0.0010903476753008814, 0.00058724674003184628, 0.017247513642613895, 0.00098228821375893568, 0.0012656988083447785, 0.00053750873292196034, 0.00012594251155030958, 0.0022962644162508043, 0.0014897877198841306, 0.00022496100123881526, 0.0021212504244370518, 0.0073883783177367086, 0.00090231458495134721, 0.00092157623176334811, 0.001799311907489401, 0.0012982192602416856, 0.0033586513465761196, 0.0014907424726515646, 0.0015358152186618985, 0.00012454563229525914, 2.9361214412134402e-05, 0.0028182911302600173, 0.0036418426458708479, 0.0033410780005623929, 0.00082791471220833735, 8.2510920018563118e-05, 5.6112263684269041e-05, 6.6448205070207018e-06, 0.00094011212515292221, 0.00093840283704651702, ...

# %%
plt.plot(it)

# %%
w.iteration = 1000
sum(w.current.weights)
# Out:
# Setting iteration to iter 1000.
# 1.0

# %%
plt.plot(flux_array)
